# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
one_h = np.random.randint(1, 7, 100)
one_h
# Out:
# array([3, 1, 1, 4, 1, 1, 6, 6, 4, 1, 3, 2, 5, 5, 2, 4, 3, 6, 1, 3, 3, 4,
#        3, 5, 6, 5, 3, 1, 1, 2, 5, 4, 6, 1, 6, 4, 6, 3, 5, 2, 5, 2, 1, 1,
#        6, 2, 4, 4, 3, 5, 3, 2, 1, 3, 5, 3, 4, 4, 2, 3, 5, 6, 3, 3, 6, 6,
#        1, 4, 2, 5, 2, 5, 1, 1, 2, 1, 5, 2, 5, 4, 4, 3, 3, 2, 6, 1, 1, 2,
#        4, 1, 3, 3, 3, 1, 2, 3, 2, 6, 4, 6])

# %%
sns.displot(x=one_h, bins=6)

# %%
one_m = np.random.randint(1, 7, 1000000)
sns.displot(x=one_m, bins=6)

# %%
np.mean(one_m)
# Out:
# np.float64(3.499084)

# %%
np.std(one_m)
# Out:
# np.float64(1.70771694403493)

# %%
one_h.reshape(25, 4).mean(axis=1)
# Out:
# array([2.25, 3.5 , 2.5 , 4.  , 3.25, 3.75, 3.75, 3.  , 4.25, 4.  , 2.25,
#        4.  , 3.25, 3.  , 3.25, 4.25, 4.25, 3.5 , 1.25, 4.  , 3.  , 2.5 ,
#        2.75, 2.25, 4.5 ])

# %%
mean4 = one_m.reshape(250000, 4).mean(axis=1)

# %%
sns.displot(x=mean4, bins= 6)
plt.xlim(0, 6)
plt.show()

# %%
np.mean(mean4)
# Out:
# np.float64(3.499084)

# %%
np.std(mean4)
# Out:
# np.float64(0.8531516049003248)

# %%
mean100 = one_m.reshape(10000, 100).mean(axis=1)

# %%
sns.displot(x=mean100, bins=6)
plt.xlim(0, 6)
# Out:
# (0.0, 6.0)

# %%
np.mean(mean100)
# Out:
# np.float64(3.499084)

# %%
np.std(mean100)
# Out:
# np.float64(0.1720726036997174)

# %%
a = np.random.normal(100, 5, 1000)
b = np.random.normal(80, 5, 1000)
bm_data = np.append(a, b)
np.random.shuffle(bm_data)

# %%
sns.displot(bm_data)

# %% [markdown]
# Alternate HYpothesis: Mean volume != 150cc
# Null Hypothesis: Mean volume = 150cc
# Alpha = 1 - 0.95 = 0.05

# %%
Z_cal = (153.8 - 150) / (2 / np.sqrt(4))
Z_cal
# Out:
# np.float64(3.8000000000000114)

# %%
from scipy.stats import norm

# %%
norm.pdf(0)
# Out:
# np.float64(0.3989422804014327)

# %%
norm.cdf(-1.96)
# Out:
# np.float64(0.024997895148220435)

# %%
norm.ppf(0.025)
# Out:
# np.float64(-1.9599639845400545)

# %%
norm.sf(1.96)
# Out:
# np.float64(0.024997895148220435)

# %%
norm.isf(0.025)
# Out:
# np.float64(1.9599639845400545)

# %%
p_value = 2 * norm.sf(Z_cal)
p_value
# Out:
# np.float64(0.0001446960878502333)
